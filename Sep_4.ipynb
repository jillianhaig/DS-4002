# %% [markdown]
# <a href="https://colab.research.google.com/github/jillianhaig/DS-4002/blob/main/Sep_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/UVADS/DS-4002
# Out:
# Cloning into 'DS-4002'...
# remote: Enumerating objects: 600, done.
# remote: Counting objects: 100% (600/600), done.
# remote: Compressing objects: 100% (330/330), done.
# remote: Total 600 (delta 340), reused 492 (delta 262), pack-reused 0 (from 0)
# Receiving objects: 100% (600/600), 3.42 MiB | 17.23 MiB/s, done.
# Resolving deltas: 100% (340/340), done.

# %%
import pandas as pd
df = pd.read_csv('/content/DS-4002/hot-dog-survey-data/Hot-Dog-Form-Fa24.csv', encoding = "latin1")
import numpy as np
import seaborn as sns

# %%
df.head()
# Out:
#    Id      Start time Completion time      Email  Name Is a hotdog a sandwich  \
# 0   1  9/1/2024 11:27  9/1/2024 11:27  anonymous   NaN                     No
# 1   2  9/1/2024 11:27  9/1/2024 11:27  anonymous   NaN                     No
# 2   3  9/1/2024 11:27  9/1/2024 11:27  anonymous   NaN                     No
# 3   4  9/1/2024 11:27  9/1/2024 11:28  anonymous   NaN                     No
# 4   5  9/1/2024 11:27  9/1/2024 11:28  anonymous   NaN                     No
#
#   Are you a UVA undergraduate student  \
# 0                                 Yes
# 1                                 Yes
# 2                                 Yes
# 3                                 Yes
# 4                                 Yes
#
#                                  What is your major?
# 0                                              Psych
# 1  Math, concentration in probability and statistics
# 2                               Systems Engineering
# ...

# %%
df.columns.unique()
# Out:
# Index(['Id', 'Start time', 'Completion time', 'Email', 'Name',
#        'Is a hotdog a sandwich', 'Are you a UVA undergraduate student',
#        'What is your major?'],
#       dtype='object')

# %%
df2 = df.drop('Start time', axis=1)
df2 = df2.drop('Completion time', axis = 1)
df2 = df2.drop('Id', axis = 1)
df2 = df2.drop('Email', axis = 1)
df2 = df2.drop('Name', axis = 1)
df2.head()
# Out:
#   Is a hotdog a sandwich Are you a UVA undergraduate student  \
# 0                     No                                 Yes
# 1                     No                                 Yes
# 2                     No                                 Yes
# 3                     No                                 Yes
# 4                     No                                 Yes
#
#                                  What is your major?
# 0                                              Psych
# 1  Math, concentration in probability and statistics
# 2                               Systems Engineering
# 3                                            CS+Math
# 4                                    wgs and History

# %%
df2['What is your major?'].replace('Econ', 'Economics')
# Out:
# 0                                                  Psych
# 1      Math, concentration in probability and statistics
# 2                                   Systems Engineering
# 3                                                CS+Math
# 4                                        wgs and History
#                              ...
# 182                                    Civil Engineering
# 183                                              Biology
# 184                                 Systems engineering
# 185                                           Statistics
# 186                                             Politics
# Name: What is your major?, Length: 187, dtype: object

# %%
df2["What is your major?"].unique()
# Out:
# array(['Psych', 'Math, concentration in probability and statistics',
#        'Systems Engineering ', 'CS+Math', 'wgs and History',
#        'Mechanical Engineering & Math with a minor in hotdog studies',
#        'Drama/Creative Writing ', 'Architecture ', 'Economics',
#        'Media Studies', 'Biology', 'Mechanical Engineering', nan,
#        'chemical engineering', 'wouldnt you like to know weather boy',
#        'Mathematics', 'arch', 'Computer Science', 'Undeclared',
#        'Civil Engineering', 'Global Studies', 'CS',
#        'Behavioral Neuroscience', 'Economics and Politics', 'physics',
#        'Behavioral Neuroscience ', 'Biomedical Engineering', 'Economics ',
#        'Media studies ', 'cs', 'Psychology ', 'Statistics',
#        'Civil Engineering ', 'American Studies', 'Systems Engineering',
#        'Environmental Science ', 'Cognitive Science ', 'Econ',
#        'neuroscience', 'Computer Science\x92s ', 'Nursing',
#        'Biomedical Engineering ', 'Neuroscience',
# ...

# %%
sns.histplot(x=df2['What is your major?'])
# Out:
# <Axes: xlabel='What is your major?', ylabel='Count'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 146 (\x92) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
